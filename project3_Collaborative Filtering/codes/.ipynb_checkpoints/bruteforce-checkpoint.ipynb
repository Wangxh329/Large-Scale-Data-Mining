# %% [markdown]
# # Q30 ~ 33

# %%
from surprise import AlgoBase
from surprise import Dataset
from surprise.model_selection import cross_validate
import numpy as np


class NaiveCollaborativeFilter(AlgoBase):
    def __init__(self):
        AlgoBase.__init__(self)

    def fit(self, trainset):
        AlgoBase.fit(self, trainset)

        # Compute rating means of each user
        
        self.trainset = trainset
        self.the_means = {}
        for key in self.trainset.ur:
            urs = self.trainset.ur[key]
            mean = np.mean([r for (_, r) in urs])
            self.the_means[key] = mean

        return self

    def estimate(self, u, i):
        if self.the_means.__contains__(u):
            return self.the_means[u]
        else:
            return 3

# %%
import pandas as pd
import os
import numpy as np
import pandas as pd
import random
from surprise import AlgoBase
from surprise import NormalPredictor
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate


class NaiveCollaborativeFilter(AlgoBase):
    def __init__(self):
        AlgoBase.__init__(self)

    def fit(self, trainset):
        AlgoBase.fit(self, trainset)

        # Compute rating means of each user
        
        self.trainset = trainset
        self.the_means = {}
        for key in self.trainset.ur:
            urs = self.trainset.ur[key]
            mean = np.mean([r for (_, r) in urs])
            self.the_means[key] = mean

        return self

    def estimate(self, u, i):
        if self.the_means.__contains__(u):
            return self.the_means[u]
        else:
            return 3


def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# read csv file
file_path = os.path.expanduser('ratings.csv')
df = pd.read_csv(file_path)
del df['timestamp']

# shuffle data
df = df.sample(frac=1).reset_index(drop=True)

# 10 fold cross validation
testlen = int(len(df) / 10)
total_rmse = 0
for i in range(10):
    # split data into 10 pieces
    sp = int(len(df) / 10 * i)
    df1 = df[0:sp]
    df2 = df[sp:sp+testlen]
    df3 = df[sp+testlen:]

    traindf = pd.concat([df1,df3],ignore_index=True)
    reader1 = Reader(rating_scale=(0, 5))
    trainset = Dataset.load_from_df(traindf[['userId', 'movieId', 'rating']], reader1)

    alg = NaiveCollaborativeFilter()
    alg.fit(trainset.build_full_trainset())

#     Q31
#     df2['size'] = df2.groupby(['movieId']).movieId.transform(np.size)
#     df2 = df2[df2['size'] > 2]

#     Q32
#     df2['size'] = df2.groupby(['movieId']).movieId.transform(np.size)
#     df2 = df2[df2['size'] <= 2]

#     Q33
#     df2['size'] = df2.groupby(['movieId']).movieId.transform(np.size)
#     df2 = df2[df2['size'] >= 5]
#     df2['var'] = df2['rating'].groupby(df2['movieId']).transform(lambda arr:np.mean((arr - arr.mean()) ** 2))
#     df2 = df2[df2['var'] >= 2]
    
    reader2 = Reader(rating_scale=(0, 5))
    testset = Dataset.load_from_df(df2[['userId', 'movieId', 'rating']], reader2)
    testset = [(u, i, r) for (u, i, r) in testset.build_full_trainset().all_ratings()]

    prediction = alg.test(testset)
    
    real = []
    est = []

    for j in range(len(prediction)):
        if not prediction[j][4]['was_impossible']:
            real.append(prediction[j][2])
            est.append(prediction[j][3])
    
    cur_rmse = rmse(np.array(real), np.array(est))
    total_rmse += cur_rmse
    print(str(i) + 'th rmse: ' + str(cur_rmse))

final_rmse = total_rmse / 10
print('final_rmse: ' + str(final_rmse))

# reader = Reader(rating_scale=(0, 5))
# Out:
# 0th rmse: 1.13501769475
# 1th rmse: 1.17037617562
# 2th rmse: 1.18077592019
# 3th rmse: 1.20399647553
# 4th rmse: 1.17155704199
# 5th rmse: 1.18510894497
# 6th rmse: 1.15123483738
# 7th rmse: 1.17172303195
# 8th rmse: 1.179792019
# 9th rmse: 1.15542318282
# final_rmse: 1.17050053242

# %%
print (prediction)
# Out:
# [Prediction(uid=0, iid=0, r_ui=4.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=501, r_ui=5.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=658, r_ui=3.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=760, r_ui=0.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=567, r_ui=5.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=223, r_ui=3.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=528, r_ui=4.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1357, r_ui=4.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1542, r_ui=3.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1700, r_ui=5.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1817, r_ui=2.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1199, r_ui=3.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=2402, r_ui=3.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=2412, r_ui=3.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=492, r_ui=3.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=2535, r_ui=4.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=542, r_ui=4.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1540, r_ui=3.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=165, r_ui=3.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=693, r_ui=1.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1288, r_ui=3.5, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=182, r_ui=3.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=3043, r_ui=5.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=2254, r_ui=3.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=3153, r_ui=4.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=3236, r_ui=3.0, est=2, details={'was_impossible': False}), Prediction(uid=0, iid=1736, r_ui=2.0, est=2, details={'was_impossible': False}), Prediction(uid=1, iid=1, r_ui=5.0, est=2.6111111111111112, details={'was_impossible': False}), Prediction(uid=1, iid=387, r_ui=5.0, est=2.6111111111111112, details={'was_impossible': False}), Prediction(uid=1, iid=809, r_ui=5.0, est=2.6111111111111112, details={'was_impossible': False}), Prediction(uid=1, iid=1988, r_ui=3.0, est=2.6111111111111112, details={'was_impossible': False}), Prediction(uid=1, iid=1087, r_ui=3.0, est=2.6111111111111112, details={'was_impossible': False}), Prediction(uid=1, iid=2022, r_ui=5.0, est=2.6111111111111112, details={'was_impossible': False}), Prediction(uid=1, iid=1740, r_ui=5.0, est=2.6111111111111112, details={'was_impossible': False}), Prediction(uid=2, iid=2, r_ui=4.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=12, r_ui=4.5, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=68, r_ui=5.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=238, r_ui=4.5, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=426, r_ui=3.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=627, r_ui=4.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=631, r_ui=2.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=706, r_ui=4.5, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=571, r_ui=4.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=870, r_ui=4.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=942, r_ui=4.0, est=3.4927536231884062, details={'was_impossible': False}), Prediction(uid=2, iid=953, r_ui=5.0, est=3.4927536231884062, details={'was_impossi ...

# %% [markdown]
# # Test

# %%
import pandas as pd
import random
from surprise import NormalPredictor
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate



# Creation of the dataframe. Column names are irrelevant.
ratings_dict = {'itemID': [1, 1, 1, 2, 2],
                'userID': [9, 32, 2, 45, 11],
                'rating': [3.0, 2.0, 4.0, 3.0, 1.0]}
df = pd.DataFrame(ratings_dict)
print (df)

# group1 = df.groupby('itemID')
# print (type(group1))
# print(group1)
# size = group1.size()
# print(type(size))
# print(size)

# df['size'] = df.groupby(['itemID']).transform(np.size)
# print(df)


# df['size'] = df.groupby(['itemID']).itemID.transform(np.size)
# df['size'] = df['itemID'].groupby(df['itemID']).transform(np.size)
# df = df[df['size'] > 2]
df['var'] = df['rating'].groupby(df['itemID']).transform(lambda arr:np.mean((arr - arr.mean()) ** 2))
print(df)
# print (df.iloc[:,[0]])

# lc.loc[lc["grade"] == "B"]

# size.iloc[size.iloc[]]
# print(type(items))
# print(items)
# Out:
#    itemID  rating  userID
# 0       1     3.0       9
# 1       1     2.0      32
# 2       1     4.0       2
# 3       2     3.0      45
# 4       2     1.0      11
#    itemID  rating  userID       var
# 0       1     3.0       9  0.666667
# 1       1     2.0      32  0.666667
# 2       1     4.0       2  0.666667
# 3       2     3.0      45  1.000000
# 4       2     1.0      11  1.000000

# %%
np.var(np.array([1, 1, 1, 2, 3, 4]))
# Out:
# 1.3333333333333333

# %%
np.var(np.array([2, 3, 4]))
# Out:
# 0.66666666666666663

# %%
df['var']
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    2.0
# 4    2.0
# Name: var, dtype: float64

# %%
df['rating'].groupby(df['itemID']).agg(lambda arr:np.mean((arr - arr.mean()) ** 2))
# Out:
# itemID
# 1    0.666667
# 2    1.000000
# Name: rating, dtype: float64

# %%
df['rating'].groupby(df['itemID']).agg(lambda arr:np.mean((arr - arr.mean()) ** 2))
